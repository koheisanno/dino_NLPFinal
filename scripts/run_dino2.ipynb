# %%
# !git clone https://github.com/koheisanno/dino_NLPFinal.git
# Out:
# Cloning into 'dino_NLPFinal'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 171 (delta 16), reused 14 (delta 11), pack-reused 143
# Receiving objects: 100% (171/171), 4.05 MiB | 3.41 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
# !nvidia-smi
# Out:
# Thu May  2 02:56:45 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   56C    P8              17W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pwd
# Out:
# /content/dino_NLPFinal

# %%
# %cd ..
# Out:
# /content/dino_NLPFinal

# %%
# %cd sts/
# Out:
# /content/dino_NLPFinal/scripts/sts

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on main: 83d7099 edit sts-x2

# %%
# !git pull https://github.com/koheisanno/dino_NLPFinal.git
# Out:
# From https://github.com/koheisanno/dino_NLPFinal
#  * branch            HEAD       -> FETCH_HEAD
# Updating 83d7099..da9c1a1
# Fast-forward
#  datasets/nli-no-debias-dataset.jsonl | 28359 +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  datasets/sts-decay-0-dataset.jsonl   | 21718 ++++++++++++++++++++++++++++++++++++++++
#  datasets/sts-def-dataset.jsonl       | 26109 +++++++++++++++++++++++++++++++++++++++++++++++-
#  datasets/x1.txt                      |  5301 +++++++++-
#  scripts/sts/postprocess_dataset.py   |     5 +-
#  scripts/sts/run_training.py          |     3 +
#  6 files changed, 81473 insertions(+), 22 deletions(-)
#  create mode 100644 datasets/nli-no-debias-dataset.jsonl
#  create mode 100644 datasets/sts-decay-0-dataset.jsonl

# %%
# !pip install -r requirements3.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 68.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 39.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 97.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 36.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 119.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
openai_api_key = userdata.get('OPENAI_API_KEY')
import os
os.environ["OPENAI_API_KEY"]=openai_api_key

# %%
# !python3 dino.py --output_dir datasets \
--task_file task_specs/sts-x2.json \
--input_file datasets/x1.txt \
--input_file_type plain \
--num_entries_per_input_and_label 2 \
--output_file_name sts-decay-0 \
--remove_duplicates \
--remove_identical_pairs \
--decay_constant 0
# Out:
# Parameters: Namespace(output_dir='datasets', task_file='task_specs/sts-x2.json', model_name='gpt2-xl', max_output_length=40, decay_constant=0.0, top_p=0.9, top_k=5, output_file_name='sts-decay-0', input_file='datasets/x1.txt', input_file_type='plain', num_entries_per_input_and_label=2, num_entries_per_label=None, batch_size=None, remove_duplicates=True, remove_identical_pairs=True, keep_outputs_without_eos=False, allow_newlines_in_outputs=False, min_num_words=-1, min_num_tokens=-1, chat_completions=False, use_openai=False, no_cuda=False, seed=42, date='01/05/2024 17:26:23')
# Done loading 5303 inputs from file 'datasets/x1.txt'
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 145kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 1.82MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.04MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:01<00:00, 1.16MB/s]
# config.json: 100% 689/689 [00:00<00:00, 4.41MB/s]
# model.safetensors: 100% 6.43G/6.43G [00:17<00:00, 373MB/s]
# ...

# %%
# !python3 scripts/sts/postprocess_dataset.py \
--input_file datasets/sts-def-dataset.jsonl \
--output_file datasets/sts-def-dataset-pp.jsonl

# %%
# !python3 scripts/sts/run_training.py \
--input_file datasets/sts-def-dataset-pp.jsonl \
--output_dir outputs
# Out:
# Parameters: Namespace(input_file='datasets/sts-def-dataset-pp.jsonl', output_dir='outputs', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='02/05/2024 04:08:53')
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2024-05-02 04:08:54 - Use pytorch device_name: cuda
# Epoch:   0% 0/1 [00:00<?, ?it/s]
# Iteration:   0% 0/1033 [00:00<?, ?it/s]
# Iteration:   0% 1/1033 [00:00<16:38,  1.03it/s]
# Iteration:   0% 3/1033 [00:01<07:02,  2.44it/s]
# Iteration:   0% 4/1033 [00:01<06:05,  2.81it/s]
# Iteration:   0% 5/1033 [00:01<05:32,  3.09it/s]
# Iteration:   1% 6/1033 [00:01<05:10,  3.30it/s]
# Iteration:   1% 7/1033 [00:02<04:56,  3.46it/s]
# ...
